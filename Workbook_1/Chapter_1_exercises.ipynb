# %%
Print('Hello world!')
# Out:
# Hello world!

# %%
print('Hello World')

# %% [markdown]
# the letter p is capital all letter in print should be small so i changed it to small

# %%
print'Hello world!')
# Out:
# Hello world!

# %%
print('Hello World')

# %% [markdown]
# missing open parentheses ,i added open parentheses

# %%
print('Hello world!)
# Out:
# Hello world!

# %%
print('Hello world')

# %% [markdown]
# missing close quotation,a string should always have a quotation

# %%
print('Hello world!'')

# %% [markdown]
# there is an extra quotation

# %%
print('Hello world')

# %%
x = 43
x = x + 1
print(x)#44
# Out:
# 44

# %%
x = 43
x = X + 1
print(x) #capital X has no value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3910bbe0e134> in <cell line: 2>()
#       1 x = 43
# ----> 2 x = X + 1
#       3 print(x) #capital X has no value
#
# NameError: name 'X' is not defined

# %%
# !git config --global user.name = 'JomelynBay'
# !git config --global user.email = 'jomelyn.bayona@students.isatu.edu.ph'
# !git config --global user.password = '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'

# %%
# !git clone https://JomelynBay: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@github.com/JomelynBay/ICT_CS2A_BAYONA.git
# Out:
# Cloning into 'ICT_CS2A_BAYONA'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 0), reused 6 (delta 0), pack-reused 0
# Receiving objects: 100% (6/6), 24.34 KiB | 1.74 MiB/s, done.

# %%
# !cp"/content/drive/MyDrive

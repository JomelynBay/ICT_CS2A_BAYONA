# %% [markdown]
# EXERCISE 1

# %% [markdown]
# Investigate on the difference between `is` and `==` given the following variables.
# ```python
# a = 2
# b = 2.0
# c = a
# ```

# %%
a=2
b=2.0
c=a

print(a is b)
#this will be False,a and b have different types (int and float), so a is b will return False because they are stored in different memory locations.
print(a == b)
#a == b will return True because their values are equal.
print(a is c)
#a and c have the same value and type, so a is c will return True as they point to the same memory location.
print( a == c)
#a == c will also return True because their values are equal.
# Out:
# False
# True
# True
# True

# %% [markdown]
# CHALLENGE 1

# %% [markdown]
# Write a program which repeatedly reads numbers until the user enters "done". Once "done" is entered, print out the total, count, and average of the numbers. If the user enters anything other than a number, detect their mistake using try and except and print an error message and skip to the next number.
#
#     Enter a number: 4
#     Enter a number: 5
#     Enter a number: bad data
#     Invalid input
#     Enter a number: 7
#     Enter a number: done
#     16 3 5.333333333333333
#
# [PEW] E5.1

# %%
total = 0
count = 0

while True:
    num = input("Enter a number: ")
    if num == 'done':
        break
    try:
        num = float(num)
    except:
        print("Invalid input")
        continue
    total += num
    count += 1

average = total / count if count > 0 else 0

print(total, count, average)
# Out:
# Enter a number: 4
# Enter a number: 5
# Enter a number: bad data
# Invalid input
# Enter a number: 7
# Enter a number: done
# 16.0 3 5.333333333333333

# %% [markdown]
# CHALLENGE 2

# %% [markdown]
# Write another program that prompts for a list of numbers as above and at the end prints out both the maximum and minimum of the numbers instead of the average.
#
# [PEW] E5.2

# %%
numbers = []
while True:
    try:
        num = input("Enter a number: ")
        if num == "done":
            break
        input_user = float(num)
        numbers.append(input_user)
    except ValueError:
        print("Invalid input")

if numbers:
    maximum = max(numbers)
    minimum = min(numbers)
    print('Maximum: ', maximum)
    print('Minimum: ', minimum)
else:
    print("No numbers were entered")
# Out:
# Enter a number: 4
# Enter a number: 5
# Enter a number: 7
# Enter a number: done
# Maximum:  7.0
# Minimum:  4.0
